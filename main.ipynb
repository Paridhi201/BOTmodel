# %%
# !pip install sentence-transformers
# !pip install pinecone-client
# !pip install openai==0.28
import openai
import pinecone
from sentence_transformers import SentenceTransformer
# !pip install --upgrade pinecone-client
import os
from pinecone import Pinecone, ServerlessSpec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.2 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit
# !pip install PyPDF2
import streamlit as st
import openai
import pinecone
from PyPDF2 import PdfReader
import os

# Set up OpenAI and Pinecone keys
pinecone_api_key = "0a****d3143"
pinecone_environment = "us-west1-gcp"
# initialize pinecone
pinecone_client = pinecone.Pinecone(
    api_key=pinecone_api_key,
    environment=pinecone_environment
)

# Streamlit app layout
st.title("RAG-based QA Bot")

# PDF upload
uploaded_file = st.file_uploader("Upload a PDF document", type="pdf")

if uploaded_file is not None:
    # Read and process PDF content
    reader = PdfReader(uploaded_file)
    document_text = ''
    for page in reader.pages:
        document_text += page.extract_text()

    # Display uploaded document content (optional)
    st.write("Uploaded document content:")
    st.write(document_text[:500])  # Display first 500 characters

    # Process and store embeddings in Pinecone
    # (This is a placeholder, assuming embeddings and indexing are done in another step)
    # Example: pinecone_index.upsert(vectors)

# Query section
query = st.text_input("Ask a question based on the document")

if st.button("Submit"):
    # Retrieve relevant context from Pinecone and generate response using OpenAI
    retrieved_context = "..."  # Placeholder for retrieval from Pinecone
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=f"Question: {query}\nContext: {retrieved_context}\nAnswer:",
        max_tokens=150,
        temperature=0.7,
    )
    answer = response.choices[0].text.strip()

    # Display answer
    st.write(f"Answer: {answer}")

    # Optionally, display retrieved document segment(s)
    st.write("Retrieved Context:")
    st.write(retrieved_context)
# Out:
# ...
# 2024-09-13 07:52:05.163 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-13 07:52:05.248
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-09-13 07:52:05.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-13 07:52:05.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-13 07:52:05.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-13 07:52:05.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-13 07:52:05.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
